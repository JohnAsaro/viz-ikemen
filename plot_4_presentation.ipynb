# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Path to your episodes log database
DB_PATH = "ppo_11_log.db"

# Connect and load data into DataFrame
with sqlite3.connect(DB_PATH) as conn:
    df = pd.read_sql_query("SELECT batch_id, winner FROM episodes WHERE winner IN (1, 2)", conn)

# Group by batch and count winners
counts = df.groupby(['batch_id', 'winner']).size().unstack(fill_value=0)

# Compute win rate for winner 1 as percentage
total_games = counts[1] + counts[2]
counts['winrate_1_percent'] = (counts[1] / total_games) * 100

# Plot
plt.figure(figsize=(10, 5))
plt.plot(counts.index, counts['winrate_1_percent'], marker='o', linestyle='-')
plt.title("Agent Winrate Test 1")
plt.xlabel("Batch ID")
plt.ylabel("Win Rate (%)")
plt.ylim(0, 100)  # Set y-axis from 0 to 100%
plt.xticks(range(int(counts.index.min()), int(counts.index.max()) + 1))  # Set x-axis ticks to integers
plt.grid(True)
plt.axhline(50, color='gray', linestyle='--', label='50% (Even)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Path to your episodes log database
DB_PATH = "ppo_12_log.db"

# Connect and load data into DataFrame
with sqlite3.connect(DB_PATH) as conn:
    df = pd.read_sql_query("SELECT batch_id, winner FROM episodes WHERE winner IN (1, 2)", conn)

# Group by batch and count winners
counts = df.groupby(['batch_id', 'winner']).size().unstack(fill_value=0)

# Compute win rate for winner 1 as percentage
total_games = counts[1] + counts[2]
counts['winrate_1_percent'] = (counts[1] / total_games) * 100

# Plot
plt.figure(figsize=(10, 5))
plt.plot(counts.index, counts['winrate_1_percent'], marker='o', linestyle='-')
plt.title("Agent Winrate Test 2")
plt.xlabel("Batch ID")
plt.ylabel("Win Rate (%)")
plt.ylim(0, 100)  # Set y-axis from 0 to 100%
plt.xticks(range(int(counts.index.min()), int(counts.index.max()) + 1))  # Set x-axis ticks to integers
plt.grid(True)
plt.axhline(50, color='gray', linestyle='--', label='50% (Even)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Path to your episodes log database
DB_PATH = "ppo_13_log.db"

# Connect and load data into DataFrame
with sqlite3.connect(DB_PATH) as conn:
    df = pd.read_sql_query("SELECT batch_id, winner FROM episodes WHERE winner IN (1, 2)", conn)

# Group by batch and count winners
counts = df.groupby(['batch_id', 'winner']).size().unstack(fill_value=0)

# Compute win rate for winner 1 as percentage
total_games = counts[1] + counts[2]
counts['winrate_1_percent'] = (counts[1] / total_games) * 100

# Plot
plt.figure(figsize=(10, 5))
plt.plot(counts.index, counts['winrate_1_percent'], marker='o', linestyle='-')
plt.title("Agent Winrate Test 3")
plt.xlabel("Batch ID")
plt.ylabel("Win Rate (%)")
plt.ylim(0, 100)  # Set y-axis from 0 to 100%
plt.xticks(range(int(counts.index.min()), int(counts.index.max()) + 1))  # Set x-axis ticks to integers
plt.grid(True)
plt.axhline(50, color='gray', linestyle='--', label='50% (Even)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Path to your episodes log database
DB_PATH = "ppo_14_log.db"

# Connect and load data into DataFrame
with sqlite3.connect(DB_PATH) as conn:
    df = pd.read_sql_query("SELECT batch_id, winner FROM episodes WHERE winner IN (1, 2)", conn)

# Group by batch and count winners
counts = df.groupby(['batch_id', 'winner']).size().unstack(fill_value=0)

# Compute win rate for winner 1 as percentage
total_games = counts[1] + counts[2]
counts['winrate_1_percent'] = (counts[1] / total_games) * 100

# Plot
plt.figure(figsize=(10, 5))
plt.plot(counts.index, counts['winrate_1_percent'], marker='o', linestyle='-')
plt.title("Agent Winrate Test 4")
plt.xlabel("Batch ID")
plt.ylabel("Win Rate (%)")
plt.ylim(0, 100)  # Set y-axis from 0 to 100%
plt.xticks(range(int(counts.index.min()), int(counts.index.max()) + 1))  # Set x-axis ticks to integers
plt.grid(True)
plt.axhline(50, color='gray', linestyle='--', label='50% (Even)')
plt.legend()
plt.tight_layout()
plt.show()
